# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import folium
import numpy as np
from numpy.lib.stride_tricks import sliding_window_view
import pandas as pd
from sympy import *
import matplotlib.pyplot as plt
from folium import plugins

# DAEGU = [35.85, 128.56]
# BUSAN = [35.1795543, 129.0756416]
JEJU = [33.30, 126.54]
KADIZ = [(39.00, 123.30),
         (37.00, 124.00),
         (30.00, 124.00),
         (30.00, 124.00),
         (30.00, 125.25),
         (30.00, 125.25),
         (32.30, 126.50),
         (32.30, 127.30),
         (34.17, 128.52),
         (35.13, 129.48),
         (36.00, 130.30),
         (37.17, 133.00),
         (39.00, 133.00),
         (39.00, 123.30)]
IEODO = [32.11753829417425, 125.16666665729801]
DOKDO = [37.24315823449135, 131.86690646281266]

def init_map():
    m = folium.Map(location = JEJU, zoom_start = 6)
    folium.PolyLine(locations = KADIZ,tooltip = 'KADIZ', color='red').add_to(m)
    folium.Marker(IEODO, popup="<i>IEODO</i>").add_to(m)
    folium.Marker(DOKDO, popup="<i>DOKDO</i>").add_to(m)
    return m

m = init_map()

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bdaf48d0aba65fc4b2921b6f1a90096 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bdaf48d0aba65fc4b2921b6f1a90096&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1bdaf48d0aba65fc4b2921b6f1a90096 = L.map(
#                 &quot;map_1bdaf48d0aba65fc4b2921b6f1a90096&quot;,
#                 {
#                     center: [33.3, 126.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b68e9b94307d14ce02b8551d4e9b5079 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#             var poly_line_81ec7c310e0c5b8d4ac83c6dacdaede0 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#             poly_line_81ec7c310e0c5b8d4ac83c6dacdaede0.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_618be807dde8a96c406d4ff9bbffabcb = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#         var popup_05d78d124b207f6d3a1e83db8fef40cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f982892996e5e107e3ad94e82439e852 = $(`&lt;div id=&quot;html_f982892996e5e107e3ad94e82439e852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_05d78d124b207f6d3a1e83db8fef40cb.setContent(html_f982892996e5e107e3ad94e82439e852);
#
#
#         marker_618be807dde8a96c406d4ff9bbffabcb.bindPopup(popup_05d78d124b207f6d3a1e83db8fef40cb)
#         ;
#
#
#
#
#             var marker_b0d6fd9c43774a32f3e177b4aaad4d97 = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#         var popup_dcb232528dd6c881327c6ffcb92417d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c861d37064cc845a09e6da1f2f7546eb = $(`&lt;div id=&quot;html_c861d37064cc845a09e6da1f2f7546eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_dcb232528dd6c881327c6ffcb92417d5.setContent(html_c861d37064cc845a09e6da1f2f7546eb);
#
#
#         marker_b0d6fd9c43774a32f3e177b4aaad4d97.bindPopup(popup_dcb232528dd6c881327c6ffcb92417d5)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def mk_row(point):
    x, y = point
    return [y * y, x, y, x * y, 1]

#return value (a, b, c, d, e, f) matches (ax^2 + by^2 + cx + by + exy + f = 0)
def find_ellipse(points):
    if len(points) != 5:
        raise ValueError
    else:
        mat = []
        constant = []
        for point in points:
            mat.append(mk_row(point))
            constant.append(-point[0]**2)
        sol = np.linalg.solve(np.array(mat), constant)
    return np.concatenate((np.array([1]), sol), axis = None)

def make_route(sol, data, input_axis, select):
    x = symbols('x', real = True)
    y = symbols('y', real = True)
    a, b, c, d, e, f = sol
    route = []
    if input_axis == 'x':
        for i in data:
            x = i
            ans = solve(a*x**2 + b*y**2 + c*x + d*y + e*x*y + f)
            if len(ans) == 0:
                print('No real solution at {}'.format(i))
                break
            if select == 'max':
                y_sol = max(ans)
                route.append([y_sol, i])
            elif select == 'min':
                y_sol = min(ans)
                route.append([y_sol, i])
    elif input_axis == 'y':
        for i in data:
            y = i
            ans = solve(a*x**2 + b*y**2 + c*x + d*y + e*x*y + f)
            if len(ans) == 0:
                print('No real solution at {}'.format(i))
                break
            if select == 'max':
                x_sol = max(ans)
                route.append([i, x_sol])
            elif select == 'min':
                x_sol = min(ans)
                route.append([i, x_sol])
    return route

# %%
# Make base route
points = [(120.15, 29.331), (125.8, 31.369), (127.42, 32.459), (129.44, 34.436), (131.35, 38.448)]

sol = find_ellipse(points)

lat_range = np.linspace(123, 131, 100)
base_route = np.array(make_route(sol, lat_range, 'x', 'min'))

print(base_route.shape)

# Make turning route
points_turing = [(122.6, 30.749), (126.4, 28.964), (128.1, 27.674), (130.63, 24.392), (131.37, 17.255)]

sol_turning = find_ellipse(points_turing)
base_turning_route = np.array(make_route(sol_turning, lat_range, 'x', 'max'))
print(base_turning_route.shape)
# Out:
# (100, 2)
# (100, 2)

# %%
folium.PolyLine(locations = base_route, tooltip = 'flight tracks', color = 'blue').add_to(m)
folium.PolyLine(locations = base_turning_route, tooltip = 'turning tracks', color = 'blue').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bdaf48d0aba65fc4b2921b6f1a90096 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bdaf48d0aba65fc4b2921b6f1a90096&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1bdaf48d0aba65fc4b2921b6f1a90096 = L.map(
#                 &quot;map_1bdaf48d0aba65fc4b2921b6f1a90096&quot;,
#                 {
#                     center: [33.3, 126.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b68e9b94307d14ce02b8551d4e9b5079 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#             var poly_line_81ec7c310e0c5b8d4ac83c6dacdaede0 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#             poly_line_81ec7c310e0c5b8d4ac83c6dacdaede0.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_618be807dde8a96c406d4ff9bbffabcb = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#         var popup_05d78d124b207f6d3a1e83db8fef40cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f982892996e5e107e3ad94e82439e852 = $(`&lt;div id=&quot;html_f982892996e5e107e3ad94e82439e852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_05d78d124b207f6d3a1e83db8fef40cb.setContent(html_f982892996e5e107e3ad94e82439e852);
#
#
#         marker_618be807dde8a96c406d4ff9bbffabcb.bindPopup(popup_05d78d124b207f6d3a1e83db8fef40cb)
#         ;
#
#
#
#
#             var marker_b0d6fd9c43774a32f3e177b4aaad4d97 = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#         var popup_dcb232528dd6c881327c6ffcb92417d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c861d37064cc845a09e6da1f2f7546eb = $(`&lt;div id=&quot;html_c861d37064cc845a09e6da1f2f7546eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_dcb232528dd6c881327c6ffcb92417d5.setContent(html_c861d37064cc845a09e6da1f2f7546eb);
#
#
#         marker_b0d6fd9c43774a32f3e177b4aaad4d97.bindPopup(popup_dcb232528dd6c881327c6ffcb92417d5)
#         ;
#
#
#
#
#             var poly_line_2421a3a28b2bec222392f2bc76b4aca7 = L.polyline(
#                 [[30.08496574842447, 123.0], [30.113682093075756, 123.08080808080808], [30.14284069908676, 123.16161616161617], [30.17244541833896, 123.24242424242425], [30.202500209824795, 123.32323232323232], [30.23300914307721, 123.4040404040404], [30.263976401764918, 123.48484848484848], [30.29540628744538, 123.56565656565657], [30.327303223493097, 123.64646464646465], [30.359671759214876, 123.72727272727273], [30.392516574156332, 123.8080808080808], [30.42584248261492, 123.88888888888889], [30.459654438371437, 123.96969696969697], [30.49395753964835, 124.05050505050505], [30.528757034315795, 124.13131313131314], [30.56405832535319, 124.21212121212122], [30.599866976583115, 124.29292929292929], [30.636188718701153, 124.37373737373737], [30.67302945560955, 124.45454545454545], [30.710395271079992, 124.53535353535354], [30.748292435765393, 124.61616161616162], [30.78672741458371, 124.6969696969697], [30.825706874495463, 124.77777777777777], [30.865237692701932, 124.85858585858585], [30.905326965296762, 124.93939393939394], [30.945982016390936, 125.02020202020202], [30.98721040775697, 125.1010101010101], [31.029019949010838, 125.18181818181819], [31.07141870839549, 125.26262626262627], [31.114415024176456, 125.34343434343434], [31.158017516719365, 125.42424242424242], [31.202235101288068, 125.5050505050505], [31.24707700161667, 125.58585858585859], [31.292552764316408, 125.66666666666667], [31.338672274178936, 125.74747474747475], [31.38544577044700

# %%
# make noise
mu, sigma = 0.1, 0.01
routes = []
route_turning = []
# route_dataset = [[] for _ in range(900)]

for i in range(100):
    s = np.random.default_rng(i).normal(mu, sigma, size=(100, 2))
    routes.append(base_route + s)
route_dataset = np.array(routes)

for i in range(100):
    s = np.random.default_rng(i).normal(mu, sigma, size=(100, 2))
    route_turning.append(base_turning_route + s)
route_turning_dataset = np.array(route_turning)

# window_size = 20
# offset = window_size // 2 - 1

# for i in range(len(routes)):
#     for j in range(0, len(routes[0]) - window_size + 1, window_size // 2):
#         pos = i * offset + j // offset
# #         print('i:%5d, j:%5d, j+w_size:%5d, pos:%5d' % (i, j, j+window_size, pos))
#         route_dataset[pos].append(routes[i:i+1, j:j+window_size, :])
    
# route_dataset = np.array(route_dataset)
# route_dataset = np.squeeze(route_dataset)
# print(route_dataset.shape)
# print(np.array_equal(routes[0, 0:window_size, :],
#                      route_dataset[0, 0:window_size, :]))
print(route_dataset.shape)
print(route_turning_dataset.shape)
# Out:
# (100, 100, 2)
# (100, 100, 2)

# %%
# show one route in dataset 
# folium.PolyLine(locations = route_dataset[0:window_size//2], tooltip = 'track with noise', color = 'orange').add_to(m)
folium.PolyLine(locations = route_dataset[0], tooltip = 'track with noise', color = 'orange').add_to(m)
folium.PolyLine(locations = route_turning_dataset[0], tooltip = 'track with noise', color = 'orange').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bdaf48d0aba65fc4b2921b6f1a90096 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bdaf48d0aba65fc4b2921b6f1a90096&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1bdaf48d0aba65fc4b2921b6f1a90096 = L.map(
#                 &quot;map_1bdaf48d0aba65fc4b2921b6f1a90096&quot;,
#                 {
#                     center: [33.3, 126.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b68e9b94307d14ce02b8551d4e9b5079 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#             var poly_line_81ec7c310e0c5b8d4ac83c6dacdaede0 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#             poly_line_81ec7c310e0c5b8d4ac83c6dacdaede0.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_618be807dde8a96c406d4ff9bbffabcb = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#         var popup_05d78d124b207f6d3a1e83db8fef40cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f982892996e5e107e3ad94e82439e852 = $(`&lt;div id=&quot;html_f982892996e5e107e3ad94e82439e852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_05d78d124b207f6d3a1e83db8fef40cb.setContent(html_f982892996e5e107e3ad94e82439e852);
#
#
#         marker_618be807dde8a96c406d4ff9bbffabcb.bindPopup(popup_05d78d124b207f6d3a1e83db8fef40cb)
#         ;
#
#
#
#
#             var marker_b0d6fd9c43774a32f3e177b4aaad4d97 = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_1bdaf48d0aba65fc4b2921b6f1a90096);
#
#
#         var popup_dcb232528dd6c881327c6ffcb92417d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c861d37064cc845a09e6da1f2f7546eb = $(`&lt;div id=&quot;html_c861d37064cc845a09e6da1f2f7546eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_dcb232528dd6c881327c6ffcb92417d5.setContent(html_c861d37064cc845a09e6da1f2f7546eb);
#
#
#         marker_b0d6fd9c43774a32f3e177b4aaad4d97.bindPopup(popup_dcb232528dd6c881327c6ffcb92417d5)
#         ;
#
#
#
#
#             var poly_line_2421a3a28b2bec222392f2bc76b4aca7 = L.polyline(
#                 [[30.08496574842447, 123.0], [30.113682093075756, 123.08080808080808], [30.14284069908676, 123.16161616161617], [30.17244541833896, 123.24242424242425], [30.202500209824795, 123.32323232323232], [30.23300914307721, 123.4040404040404], [30.263976401764918, 123.48484848484848], [30.29540628744538, 123.56565656565657], [30.327303223493097, 123.64646464646465], [30.359671759214876, 123.72727272727273], [30.392516574156332, 123.8080808080808], [30.42584248261492, 123.88888888888889], [30.459654438371437, 123.96969696969697], [30.49395753964835, 124.05050505050505], [30.528757034315795, 124.13131313131314], [30.56405832535319, 124.21212121212122], [30.599866976583115, 124.29292929292929], [30.636188718701153, 124.37373737373737], [30.67302945560955, 124.45454545454545], [30.710395271079992, 124.53535353535354], [30.748292435765393, 124.61616161616162], [30.78672741458371, 124.6969696969697], [30.825706874495463, 124.77777777777777], [30.865237692701932, 124.85858585858585], [30.905326965296762, 124.93939393939394], [30.945982016390936, 125.02020202020202], [30.98721040775697, 125.1010101010101], [31.029019949010838, 125.18181818181819], [31.07141870839549, 125.26262626262627], [31.114415024176456, 125.34343434343434], [31.158017516719365, 125.42424242424242], [31.202235101288068, 125.5050505050505], [31.24707700161667, 125.58585858585859], [31.292552764316408, 125.66666666666667], [31.338672274178936, 125.74747474747475], [31.38544577044700

# %%
# Split datasets
ratio = 0.7
boundary = int(len(route_dataset) * ratio)

train_dataset = route_dataset[:boundary, :, :]
test_dataset = route_dataset[boundary:, :, :]

print(train_dataset.shape, test_dataset.shape)
# Out:
# (70, 100, 2) (30, 100, 2)

# %%
# Split turning datasets
ratio = 0.7
boundary = int(len(route_turning_dataset) * ratio)

train_turning_dataset = route_turning_dataset[:boundary, :, :]
test_turning_dataset = route_turning_dataset[boundary:, :, :]

print(train_turning_dataset.shape, test_turning_dataset.shape)
# Out:
# (70, 100, 2) (30, 100, 2)

# %%
standard_base = StandardScaler()
minmax_base = MinMaxScaler()
standard_turning = StandardScaler()
minmax_turning = MinMaxScaler()

class RouteDataset(Dataset): 
    def __init__(self, train=True, base=True):    
        # Scaling
        if (base):
            self.dataset = train_dataset if train == True else test_dataset
        else:
            self.dataset = train_turning_dataset if train == True else test_turning_dataset
        self.boundary = int(len(self.dataset[0]) * 0.05)
        
        self.x_data = self.dataset[:, :self.boundary, :]
        self.y_data = self.dataset[:, self.boundary:, :]
        
        if(base):
            self.x_data = standard_base.fit_transform(self.x_data.reshape(-1, self.x_data.shape[-1])).reshape(self.x_data.shape)
            self.y_data = minmax_base.fit_transform(self.y_data.reshape(-1, self.y_data.shape[-1])).reshape(self.y_data.shape)
        else:
            self.x_data = standard_turning.fit_transform(self.x_data.reshape(-1, self.x_data.shape[-1])).reshape(self.x_data.shape)
            self.y_data = minmax_turning.fit_transform(self.y_data.reshape(-1, self.y_data.shape[-1])).reshape(self.y_data.shape) 
            
    def __len__(self): 
        return len(self.x_data)
    
    def __getitem__(self, idx): 
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        return x, y

# %%
batch_size = 16

train_loader = DataLoader(dataset=RouteDataset(train=True), 
                          batch_size=batch_size)
test_loader = DataLoader(dataset=RouteDataset(train=False), 
                         batch_size=batch_size)

train_turning_loader = DataLoader(dataset=RouteDataset(train=True, base=False), 
                                  batch_size=batch_size)
test_turning_loader = DataLoader(dataset=RouteDataset(train=False, base=False), 
                                 batch_size=batch_size)

for i, (x, y) in enumerate(train_loader):
    print(i, x.shape, y.shape)
for i, (x, y) in enumerate(test_loader):
    print(i, x.shape, y.shape)
for i, (x, y) in enumerate(train_turning_loader):
    print(i, x.shape, y.shape)
for i, (x, y) in enumerate(test_turning_loader):
    print(i, x.shape, y.shape)
# Out:
# 0 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 1 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 2 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 3 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 4 torch.Size([6, 5, 2]) torch.Size([6, 95, 2])
# 0 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 1 torch.Size([14, 5, 2]) torch.Size([14, 95, 2])
# 0 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 1 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 2 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 3 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 4 torch.Size([6, 5, 2]) torch.Size([6, 95, 2])
# 0 torch.Size([16, 5, 2]) torch.Size([16, 95, 2])
# 1 torch.Size([14, 5, 2]) torch.Size([14, 95, 2])

# %%
# Model definition
device = 'cpu'

class LSTM(nn.Module):
    def __init__(self,output_size,input_size,hidden_size,num_layers,seq_length):
        super(LSTM,self).__init__()
        self.output_size = output_size
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length

        self.lstm = nn.LSTM(input_size=input_size , hidden_size=hidden_size , num_layers=num_layers, batch_first=True)
        self.fc_1 = nn.Linear(hidden_size,128)
        self.fc = nn.Linear(128,output_size)

        self.relu = nn.ReLU()

    def forward(self,x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0),self.hidden_size)).to(device)
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0),self.hidden_size)).to(device)

        output, (hn,cn) = self.lstm(x,(h_0,c_0))

        hn = hn.view(-1, self.hidden_size)
        out = self.relu(hn)
        out = self.fc_1(out)
        out = self.relu(out)
        out = self.fc(out)
        return out

# %%
num_epochs = 100
learning_rate = 0.0001

input_size = 2
hidden_size = 32
num_layers = 1
# output_size = 100
# seq_length = 50
# output_size = 20
# seq_length = 10
total_seq_length = 100
seq_length = 5
output_size = (total_seq_length - seq_length) * input_size

print_every = 10

base_model = LSTM(output_size, input_size, hidden_size, num_layers, seq_length)
turning_model = LSTM(output_size, input_size, hidden_size, num_layers, seq_length)

loss_function = torch.nn.MSELoss()
base_optimizer = torch.optim.Adam(base_model.parameters(), lr = learning_rate)
turning_optimizer = torch.optim.Adam(turning_model.parameters(), lr = learning_rate)

# %%
# Base Model trainig
for epoch in range(1, num_epochs+1):
    for i, (x_train, y_train) in enumerate(train_loader):
        x_train = Variable(x_train.view(-1, seq_length, input_size))
        y_train = Variable(y_train.view(-1, output_size))

        base_optimizer.zero_grad()
        outputs = base_model(x_train)
#         import pdb; pdb.set_trace()
        loss = loss_function(outputs, y_train)

        loss.backward()
        base_optimizer.step()

    if epoch % print_every == 0:
        print("[Epoch %3d] loss : %1.5f" % (epoch, loss.item()))
# Out:
# [Epoch  10] loss : 0.23587
# [Epoch  20] loss : 0.19524
# [Epoch  30] loss : 0.14370
# [Epoch  40] loss : 0.08117
# [Epoch  50] loss : 0.02557
# [Epoch  60] loss : 0.00463
# [Epoch  70] loss : 0.00077
# [Epoch  80] loss : 0.00017
# [Epoch  90] loss : 0.00008
# [Epoch 100] loss : 0.00006

# %%
# Turning Model trainig
for epoch in range(1, num_epochs+1):
    for i, (x_train, y_train) in enumerate(train_turning_loader):
        x_train = Variable(x_train.view(-1, seq_length, input_size))
        y_train = Variable(y_train.view(-1, output_size))

        turning_optimizer.zero_grad()
        outputs = turning_model(x_train)
#         import pdb; pdb.set_trace()
        loss = loss_function(outputs, y_train)

        loss.backward()
        turning_optimizer.step()

    if epoch % print_every == 0:
        print("[Epoch %3d] loss : %1.5f" % (epoch, loss.item()))
# Out:
# [Epoch  10] loss : 0.36643
# [Epoch  20] loss : 0.31321
# [Epoch  30] loss : 0.23730
# [Epoch  40] loss : 0.13446
# [Epoch  50] loss : 0.03855
# [Epoch  60] loss : 0.00648
# [Epoch  70] loss : 0.00133
# [Epoch  80] loss : 0.00031
# [Epoch  90] loss : 0.00012
# [Epoch 100] loss : 0.00008

# %%
# Base Model testing
total, total_loss = 0, 0.0
base_model.eval()

for i, (x_test, y_test) in enumerate(test_loader):
    x_test = Variable(x_test.view(-1, seq_length, input_size))
    y_test = Variable(y_test.view(-1, output_size))

    outputs = base_model(x_test)
    loss = loss_function(outputs, y_test)

    total += y_test.size(0)
    total_loss += loss.item()
        
avg_loss = total_loss / total
print('Test Loss : %1.5f' % avg_loss)
# Out:
# Test Loss : 0.00000

# %%
# Turning Model testing
total, total_loss = 0, 0.0
turning_model.eval()

for i, (x_test, y_test) in enumerate(test_turning_loader):
    x_test = Variable(x_test.view(-1, seq_length, input_size))
    y_test = Variable(y_test.view(-1, output_size))

    outputs = turning_model(x_test)
    loss = loss_function(outputs, y_test)

    total += y_test.size(0)
    total_loss += loss.item()
        
avg_loss = total_loss / total
print('Test Loss : %1.5f' % avg_loss)
# Out:
# Test Loss : 0.00001

# %%
for (x, y) in test_loader:
  print(x.size())
  print(x)
# Out:
# torch.Size([16, 5, 2])
# tensor([[[-1.3634, -1.4988],
#          [-0.4771, -0.7431],
#          [ 0.3066, -0.1261],
#          [ 0.7701,  0.7063],
#          [ 1.5195,  1.3414]],
#
#         [[-1.3331, -1.3651],
#          [-0.7104, -0.7120],
#          [ 0.0996,  0.0465],
#          [ 0.7431,  0.5839],
#          [ 1.2230,  1.3874]],
#
#         [[-1.5747, -1.4128],
#          [-0.5507, -0.8517],
#          [-0.3365, -0.0818],
#          [ 0.8941,  0.8053],
#          [ 1.4274,  1.4533]],
#
#         [[-1.5953, -1.3424],
#          [-0.7727, -0.6784],
#          [ 0.0615, -0.1682],
#          [ 0.7790,  0.6236],
#          [ 1.0682,  1.5117]],
#
#         [[-1.2877, -1.3923],
#          [-0.5160, -0.7242],
#          [-0.2142, -0.0262],
#          [ 0.6735,  0.7234],
#          [ 1.3089,  1.4853]],
#
#         [[-1.5988, -1.3757],
#          [-0.5919, -0.6661],
#          [ 0.1013,  0.0041],
#          [ 0.7661,  0.8009],
#          [ 1.7785,  1.4009]],
#
#         [[-1.4753, -1.2574],
#          [-0.4601, -0.6599],
#          [ 0.2306, -0.1348],
#          [ 0.8082,  0.8333],
#          [ 1.6728,  1.2779]],
#
#         [[-1.2461, -1.4602],
#          [-0.0758, -0.8448],
#          [ 0.1362, -0.0106],
#          [ 0.5825,  0.8012],
#          [ 0.9365,  1.3281]],
#
#         [[-1.4996, -1.3758],
#          [-0.7727, -0.7998],
#          [ 0.1472, -0.0281],
#          [ 0.6745,  0.7712],
#          [ 1.9346,  1.3722]],
#
#         [[-1.2019, -1.4745],
#          [-0.5910, -0.7506],
#          [ 0.2821,  0.0025],
#          [ 0.2467,  0.7561],
#          [ 1.2159,  1.4733]],
#
#         [[-1.1230, -1.4463],
#          [-0.8183, -0.8091],
#          [-0.2860,  0.2250],
#          [ 0.6944,  0.7178],
#          [ 1.5528,  1.4396]],
#
#         [[-1.2144, -1.3426],
#          [-0.8502, -0.6604],
#          [ 0.2667,  0.0058],
#          [ 0.9716,  0.8084],
#          [ 1.2970,  1.4725]],
#
#         [[-0.9476, -1.3206],
#          [-0.4307, -0.7891],
#          [-0.1544, -0.0645],
#          [ 0.2720,  0.6718],
#          [ 1.5524,  1.4308]],
#
#         [[-1.6811, -1.4470],
#          [-0.6944, -0.6699],
#          [-0.2533,  0.1056],
#          [ 0.7138,  0.6615],
#          [ 1.0029,  1.3557]],
#
#         [[-1.6997, -1.4421],
#          [-1.2285, -0.6130],
#          [-0.2936, -0.0129],
#          [ 0.8103,  0.7206],
#          [ 1.1564,  1.5135]],
#
#         [[-1.0469, -1.5074],
#          [-0.8983, -0.7848],
#          [-0.0385,  0.0356],
#          [ 0.7633,  0.7331],
#          [ 1.1417,  1.3841]]])
# torch.Size([14, 5, 2])
# tensor([[[-1.7226, -1.4326],
#          [-0.5311, -0.6411],
#          [-0.2014,  0.0465],
#          [ 0.7546,  0.7177],
#          [ 1.4051,  1.2967]],
#
#         [[-1.2321, -1.4218],
#          [-0.5743, -0.5682],
#          [-0.1699, -0.0501],
#          [ 0.8530,  0.7112],
#          [ 1.7174,  1.3235]],
#
#         [[-1.5123, -1.4576],
#          [-0.9281, -0.6657],
#          [-0.1065,  0.0827],
#          [ 0.8829,  0.6636],
#          [ 1.6982,  1.3210]],
#
#         [[-1.4618, -1.4343],
#          [-0.4383, -0.6782],
#          [ 0.2002,  0.0313],
#          [ 0.7823,  0.7183],
#          [ 1.4865,  1.3365]],
#
#         [[-0.9278, -1.4522],
#          [-0.7102, -0.6585],
#          [-0.0877,  0.0025],
#          [ 1.0672,  0.8130],
#          [ 1.5028,  1.4145]],
#
#         [[-1.3162, -1.3471],
#          [-0.9863, -0.7487],
#          [ 0.1218, -0.0169],
#          [ 0.5940,  0.6869],
#          [ 1.2113,  1.3624]],
#
#         [[-1.9052, -1.4988],
#          [-0.9948, -0.8221],
#          [-0.1111,  0.0981],
#          [ 0.4931,  0.7047],
#          [ 1.2962,  1.3959]],
#
#         [[-1.0901, -1.4814],
#          [-0.4145, -0.6490],
#          [ 0.1170, -0.0620],
#          [ 0.3963,  0.7814],
#          [ 1.4035,  1.5037]],
#
#         [[-1.1119, -1.3655],
#          [-0.8373, -0.6886],
#          [ 0.0438, -0.0093],
#          [ 0.7832,  0.6928],
#          [ 1.2316,  1.3159]],
#
#         [[-1.3913, -1.4322],
#          [-0.2001, -0.6937],
#          [-0.1346,  0.1246],
#          [ 0.8620,  0.7304],
#          [ 1.4827,  1.3199]],
#
#         [[-1.5526, -1.2851],
#          [-0.8735, -0.8624],
#          [-0.1109,  0.1463],
#          [ 0.4649,  0.7965],
#          [ 1.2384,  1.3418]],
#
#         [[-1.4041, -1.3090],
#          [-0.7829, -0.7903],
#          [-0.3078, -0.0784],
#          [ 0.5523,  0.5901],
#          [ 1.5852,  1.2979]],
#
#         [[-1.5940, -1.5191],
#          [-0.5564, -0.6440],
#          [ 0.0825,  0.0951],
#          [ 0.5934,  0.7596],
#          [ 1.4428,  1.4364]],
#
#         [[-1.3254, -1.4510],
#          [-0.6735, -0.6443],
#          [-0.4190,  0.1491],
#          [ 0.5588,  0.6559],
#          [ 1.1135,  1.4956]]])

# %%
# Visualization (Base)
for (x, y) in test_loader:
    x = Variable(x[0].view(-1, seq_length, input_size))
    y = Variable(y[0].view(-1, output_size))
    y_predicted = base_model(x)
    
    x = x.view(seq_length, input_size).data.detach().cpu().numpy()
    y = y.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()
    y_predicted = y_predicted.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()    
        
    x = standard_base.inverse_transform(x)
    y = minmax_base.inverse_transform(y)
    y_predicted = minmax_base.inverse_transform(y_predicted)
    
    m = init_map()
    
    folium.PolyLine(locations = x,color = 'blue',tooltip = 'Real Trajectory').add_to(m)
    folium.PolyLine(locations = y,color = 'green',tooltip = 'Predicted Trajectory').add_to(m)
    folium.PolyLine(locations = y_predicted,color = 'orange',tooltip = 'Predicted Trajectory').add_to(m)
    
    break
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_709dcaa33ecec10f87e77df70d9ae163 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_709dcaa33ecec10f87e77df70d9ae163&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_709dcaa33ecec10f87e77df70d9ae163 = L.map(
#                 &quot;map_709dcaa33ecec10f87e77df70d9ae163&quot;,
#                 {
#                     center: [33.3, 126.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e12c3013b921ec9e98015bea85a7eb56 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_709dcaa33ecec10f87e77df70d9ae163);
#
#
#             var poly_line_e3a45ed0ce232f6204492eb5977889a1 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_709dcaa33ecec10f87e77df70d9ae163);
#
#
#             poly_line_e3a45ed0ce232f6204492eb5977889a1.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_de756d8c219ff87f750f8624367d6786 = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_709dcaa33ecec10f87e77df70d9ae163);
#
#
#         var popup_500f0c6f5cbbe3ec97d401ebafdd2676 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9ba9306b2747a9ffd042ad23c145c7e1 = $(`&lt;div id=&quot;html_9ba9306b2747a9ffd042ad23c145c7e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_500f0c6f5cbbe3ec97d401ebafdd2676.setContent(html_9ba9306b2747a9ffd042ad23c145c7e1);
#
#
#         marker_de756d8c219ff87f750f8624367d6786.bindPopup(popup_500f0c6f5cbbe3ec97d401ebafdd2676)
#         ;
#
#
#
#
#             var marker_3f5c31200c139fc840ed7c9c9e38f6c3 = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_709dcaa33ecec10f87e77df70d9ae163);
#
#
#         var popup_b0e115f27672744c2ae822d414b0473e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5b3d9c14f5200220f5b08a6c4014ee1d = $(`&lt;div id=&quot;html_5b3d9c14f5200220f5b08a6c4014ee1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_b0e115f27672744c2ae822d414b0473e.setContent(html_5b3d9c14f5200220f5b08a6c4014ee1d);
#
#
#         marker_3f5c31200c139fc840ed7c9c9e38f6c3.bindPopup(popup_b0e115f27672744c2ae822d414b0473e)
#         ;
#
#
#
#
#             var poly_line_b1a649a4f8704031e6ebfd6c603d5322 = L.polyline(
#                 [[30.184133529663086, 123.08988189697266], [30.222745895385742, 123.17635345458984], [30.25688362121582, 123.2469711303711], [30.27707290649414, 123.34223175048828], [30.309717178344727, 123.41490936279297]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_709dcaa33ecec10f87e77df70d9ae163);
#
#
#             poly_line_b1a649a4f8704031e6ebfd6c603d5322.bindTooltip(
#                 `&lt;div&gt;
#                      Real Trajectory
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_448df066f5550f2179ff8dffe43bdff3 = L.polyline(
#                 [[30.335729598999023, 123.51921081542969], [30.352806091308594, 123.58067321777344], [30.405820846557617, 123.66001892089844], [30.442522048950195, 123.74140930175781], [30.45622444152832, 123.83722686767578], [30.49465560913086, 123.91924285888672], [30.53337287902832, 123.98080444335938], [30.574604034423828, 124.07633209228516], [30.602102

# %%
# Visualization (Turning)
for (x, y) in test_turning_loader:
    x = Variable(x[0].view(-1, seq_length, input_size))
    y = Variable(y[0].view(-1, output_size))
    y_predicted = turning_model(x)
    
    x = x.view(seq_length, input_size).data.detach().cpu().numpy()
    y = y.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()
    y_predicted = y_predicted.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()    
        
    x = standard_turning.inverse_transform(x)
    y = minmax_turning.inverse_transform(y)
    y_predicted = minmax_turning.inverse_transform(y_predicted)
    
    m = init_map()
    
    folium.PolyLine(locations = x,color = 'blue',tooltip = 'Real Trajectory').add_to(m)
    folium.PolyLine(locations = y,color = 'green',tooltip = 'Predicted Trajectory').add_to(m)
    folium.PolyLine(locations = y_predicted,color = 'orange',tooltip = 'Predicted Trajectory').add_to(m)
    
    break
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2472af91605b5b899a52d96f71b9e6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2472af91605b5b899a52d96f71b9e6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e2472af91605b5b899a52d96f71b9e6b = L.map(
#                 &quot;map_e2472af91605b5b899a52d96f71b9e6b&quot;,
#                 {
#                     center: [33.3, 126.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e56c7bbeab18c48e932cbf03f75a647 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e2472af91605b5b899a52d96f71b9e6b);
#
#
#             var poly_line_5d12021c14045ee59aa4a766d4d89791 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e2472af91605b5b899a52d96f71b9e6b);
#
#
#             poly_line_5d12021c14045ee59aa4a766d4d89791.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_459fb061c4200e58d3ae59e340ab02e8 = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_e2472af91605b5b899a52d96f71b9e6b);
#
#
#         var popup_d1f14174eb1e98f7139a014c3d711a54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b3283a9a7b7e480610a73cb748b78623 = $(`&lt;div id=&quot;html_b3283a9a7b7e480610a73cb748b78623&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_d1f14174eb1e98f7139a014c3d711a54.setContent(html_b3283a9a7b7e480610a73cb748b78623);
#
#
#         marker_459fb061c4200e58d3ae59e340ab02e8.bindPopup(popup_d1f14174eb1e98f7139a014c3d711a54)
#         ;
#
#
#
#
#             var marker_88f16240ab5fe1f4d82c57f7626731b6 = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_e2472af91605b5b899a52d96f71b9e6b);
#
#
#         var popup_71ec74ca9f6fca29257f86435f5785a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1cfdc784743ae48afe82f20e2e053ab0 = $(`&lt;div id=&quot;html_1cfdc784743ae48afe82f20e2e053ab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_71ec74ca9f6fca29257f86435f5785a2.setContent(html_1cfdc784743ae48afe82f20e2e053ab0);
#
#
#         marker_88f16240ab5fe1f4d82c57f7626731b6.bindPopup(popup_71ec74ca9f6fca29257f86435f5785a2)
#         ;
#
#
#
#
#             var poly_line_356dee910003639dd5442e53c8ce25a1 = L.polyline(
#                 [[30.710906982421875, 123.08988189697266], [30.69186019897461, 123.17635345458984], [30.667478561401367, 123.2469711303711], [30.628280639648438, 123.34223175048828], [30.60066032409668, 123.41490936279297]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e2472af91605b5b899a52d96f71b9e6b);
#
#
#             poly_line_356dee910003639dd5442e53c8ce25a1.bindTooltip(
#                 `&lt;div&gt;
#                      Real Trajectory
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_c549f990c28e2560375f37ea4eab87b0 = L.polyline(
#                 [[30.565521240234375, 123.51921081542969], [30.520553588867188, 123.58067321777344], [30.5106143951416, 123.66001892089844], [30.483449935913086, 123.74140930175781], [30.43236541748047, 123.83722686767578], [30.40507698059082, 123.91924285888672], [30.37712860107422, 123.98080444335938], [30.350736618041992, 124.07633209228516], [30.30965042

# %%
# Animiation

lines = []

for (x, y) in test_loader:
    x = Variable(x[0].view(-1, seq_length, input_size))
    y = Variable(y[0].view(-1, output_size))
    y_predicted = base_model(x)
    
    x = x.view(seq_length, input_size).data.detach().cpu().numpy()
    y = y.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()
    y_predicted = y_predicted.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()    
        
    x = standard_base.inverse_transform(x)
    y = minmax_base.inverse_transform(y)
    y_predicted = minmax_base.inverse_transform(y_predicted)
    
    # Swap latitude, longitude 
    x[:,[0, 1]] = x[:,[1, 0]]
    y[:,[0, 1]] = y[:,[1, 0]]
    y_predicted[:,[0, 1]] = y_predicted[:,[1, 0]]
     
    lines.append({
        "coordinates": x.tolist(),
        "dates": ['2022-09-05T{hour:02d}:{minute:02d}:00'.format(hour=0, minute=5 * i) for i in range(len(x))],
        "color": "blue"
    })
    lines.append({
        "coordinates": y_predicted.tolist(),
        "dates": ['2022-09-05T{hour:02d}:{minute:02d}:00'.format(hour=1 + i // 60, 
                                                                 minute=i % 60) for i in range(len(y_predicted))],
        "color": "orange"
    })
    lines.append({
        "coordinates": y.tolist(),
        "dates": ['2022-09-05T{hour:02d}:{minute:02d}:00'.format(hour=3 + i // 60, 
                                                                 minute=i % 60) for i in range(len(y))],
        "color": "blue"
    })
    
    break

for (x, y) in test_turning_loader:
    x = Variable(x[0].view(-1, seq_length, input_size))
    y = Variable(y[0].view(-1, output_size))
    y_predicted = turning_model(x)
    
    x = x.view(seq_length, input_size).data.detach().cpu().numpy()
    y = y.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()
    y_predicted = y_predicted.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()    
        
    x = standard_turning.inverse_transform(x)
    y = minmax_turning.inverse_transform(y)
    y_predicted = minmax_turning.inverse_transform(y_predicted)
    
    # Swap latitude, longitude 
    x[:,[0, 1]] = x[:,[1, 0]]
    y[:,[0, 1]] = y[:,[1, 0]]
    y_predicted[:,[0, 1]] = y_predicted[:,[1, 0]]
     
    lines.append({
        "coordinates": y_predicted.tolist(),
        "dates": ['2022-09-05T{hour:02d}:{minute:02d}:00'.format(hour=1 + i // 60, 
                                                                 minute=i % 60) for i in range(len(y_predicted))],
        "color": "orange"
    })
    
    break

features = [
    {
        "type": "Feature",
        "geometry": {
            "type": "LineString",
            "coordinates": line["coordinates"],
        },
        "properties": {
            "times": line["dates"],
            "style": {
                "color": line["color"]
            },
        },
    }
    for line in lines
]

m = init_map()
plugins.TimestampedGeoJson(
    {
        "type": "FeatureCollection",
        "features": features,
    },
    period="PT1M",
    transition_time=100,
    add_last_point=False,
).add_to(m)

header_html = '''
             <div style='display:flex; justify-content:space-around;'>
             <h3 style="font-size:16px; color:blue; text-align:left;">파란색 : 실제 항적경로</h3>
             <h3 style="font-size:16px; color:orange; text-align:left;">주황색 : LSTM 모델의 예측 항적경로</h3>
             </div>
             '''

m.get_root().html.add_child(folium.Element(header_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2544d5260a5407c97a6660932595ce58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/2.0.0/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;div style=&#x27;display:flex; justify-content:space-around;&#x27;&gt;
#              &lt;h3 style=&quot;font-size:16px; color:blue; text-align:left;&quot;&gt;파란색 : 실제 항적경로&lt;/h3&gt;
#              &lt;h3 style=&quot;font-size:16px; color:orange; text-align:left;&quot;&gt;주황색 : LSTM 모델의 예측 항적경로&lt;/h3&gt;
#              &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2544d5260a5407c97a6660932595ce58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2544d5260a5407c97a6660932595ce58 = L.map(
#                 &quot;map_2544d5260a5407c97a6660932595ce58&quot;,
#                 {
#                     center: [33.3, 126.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4dd3332679ff71d4c6e41c4bc87432e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2544d5260a5407c97a6660932595ce58);
#
#
#             var poly_line_29625171a87cdb4cc2a0bd288d0bad6d = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2544d5260a5407c97a6660932595ce58);
#
#
#             poly_line_29625171a87cdb4cc2a0bd288d0bad6d.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6af5cb3345efe764b363ebe85061f4d3 = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_2544d5260a5407c97a6660932595ce58);
#
#
#         var popup_7c33759ae0f2cf100702969aa18a6694 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bea30a3bde6188f141c88c8804abb608 = $(`&lt;div id=&quot;html_bea30a3bde6188f141c88c8804abb608&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_7c33759ae0f2cf100702969aa18a6694.setContent(html_bea30a3bde6188f141c88c8804abb608);
#
#
#         marker_6af5cb3345efe764b363ebe85061f4d3.bindPopup(popup_7c33759ae0f2cf100702969aa18a6694)
#         ;
#
#
#
#
#             var marker_3e7676358fa5e8a0151c9d3f5b132bc5 = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_2544d5260a5407c97a6660932595ce58);
#
#
#         var popup_31f5942f57424791a45dd44d19b1f333 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_007fed30feb3da739a4ab7f80ffdaa42 = $(`&lt;div id=&quot;html_007fed30feb3da739a4ab7f80ffdaa42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_31f5942f57424791a45dd44d19b1f333.setContent(html_007fed30feb3da739a4ab7f80ffdaa42);
#
#
#         marker_3e7676358fa5e8a0151c9d3f5b132bc5.bindPopup(popup_31f5942f57424791a45dd44d19b1f333)
#         ;
#
#
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format

# %%
# Animiation

lines = []

for (x, y) in test_loader:
    x = Variable(x[0].view(-1, seq_length, input_size))
    y = Variable(y[0].view(-1, output_size))
    y_predicted = base_model(x)
    
    x = x.view(seq_length, input_size).data.detach().cpu().numpy()
    y = y.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()
    y_predicted = y_predicted.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()    
        
    x = standard_base.inverse_transform(x)
    y = minmax_base.inverse_transform(y)
    y_predicted = minmax_base.inverse_transform(y_predicted)
    
    # Swap latitude, longitude 
    x[:,[0, 1]] = x[:,[1, 0]]
    y[:,[0, 1]] = y[:,[1, 0]]
    y_predicted[:,[0, 1]] = y_predicted[:,[1, 0]]
     
    lines.append({
        "coordinates": x.tolist(),
        "dates": ['2022-09-05T{hour:02d}:{minute:02d}:00'.format(hour=0, minute=5 * i) for i in range(len(x))],
        "color": "blue"
    })
    lines.append({
        "coordinates": y_predicted.tolist(),
        "dates": ['2022-09-05T{hour:02d}:{minute:02d}:00'.format(hour=1 + i // 60, 
                                                                 minute=i % 60) for i in range(len(y_predicted))],
        "color": "orange"
    })
    lines.append({
        "coordinates": y.tolist(),
        "dates": ['2022-09-05T{hour:02d}:{minute:02d}:00'.format(hour=3 + i // 60, 
                                                                 minute=i % 60) for i in range(len(y))],
        "color": "blue"
    })
    
    break

for (x, y) in test_turning_loader:
    x = Variable(x[0].view(-1, seq_length, input_size))
    y = Variable(y[0].view(-1, output_size))
    y_predicted = turning_model(x)
    
    x = x.view(seq_length, input_size).data.detach().cpu().numpy()
    y = y.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()
    y_predicted = y_predicted.view((total_seq_length - seq_length), input_size).data.detach().cpu().numpy()    
        
    x = standard_turning.inverse_transform(x)
    y = minmax_turning.inverse_transform(y)
    y_predicted = minmax_turning.inverse_transform(y_predicted)
    
    # Swap latitude, longitude 
    x[:,[0, 1]] = x[:,[1, 0]]
    y[:,[0, 1]] = y[:,[1, 0]]
    y_predicted[:,[0, 1]] = y_predicted[:,[1, 0]]
     
    lines.append({
        "coordinates": y_predicted.tolist(),
        "dates": ['2022-09-05T{hour:02d}:{minute:02d}:00'.format(hour=1 + i // 60, 
                                                                 minute=i % 60) for i in range(len(y_predicted))],
        "color": "orange"
    })
    
    break

features = [
    {
        "type": "Feature",
        "geometry": {
            "type": "LineString",
            "coordinates": line["coordinates"],
        },
        "properties": {
            "times": line["dates"],
            "style": {
                "color": line["color"]
            },
        },
    }
    for line in lines
]

m = init_map()
plugins.TimestampedGeoJson(
    {
        "type": "FeatureCollection",
        "features": features,
    },
    period="PT1M",
    transition_time=100,
    add_last_point=False,
).add_to(m)

header_html = '''
             <div style='display:flex; justify-content:space-around;'>
             <h3 style="font-size:16px; color:blue; text-align:left;">파란색 : 실제 항적경로</h3>
             <h3 style="font-size:16px; color:orange; text-align:left;">주황색 : LSTM 모델의 예측 항적경로</h3>
             </div>
             '''

m.get_root().html.add_child(folium.Element(header_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83b3f7107cf9899868137e567f1c1ecf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/2.0.0/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;div style=&#x27;display:flex; justify-content:space-around;&#x27;&gt;
#              &lt;h3 style=&quot;font-size:16px; color:blue; text-align:left;&quot;&gt;파란색 : 실제 항적경로&lt;/h3&gt;
#              &lt;h3 style=&quot;font-size:16px; color:orange; text-align:left;&quot;&gt;주황색 : LSTM 모델의 예측 항적경로&lt;/h3&gt;
#              &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83b3f7107cf9899868137e567f1c1ecf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_83b3f7107cf9899868137e567f1c1ecf = L.map(
#                 &quot;map_83b3f7107cf9899868137e567f1c1ecf&quot;,
#                 {
#                     center: [33.3, 126.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f146acdecde67f0801ff97ad12b2f8f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83b3f7107cf9899868137e567f1c1ecf);
#
#
#             var poly_line_b8f7050b83d1bff3704cb0c8c6063d9a = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83b3f7107cf9899868137e567f1c1ecf);
#
#
#             poly_line_b8f7050b83d1bff3704cb0c8c6063d9a.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7eed80f3234357a6d78d586f8bf91294 = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_83b3f7107cf9899868137e567f1c1ecf);
#
#
#         var popup_72de41b1f68cabfbd9ae7992ef9be46b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_22cb308d4381fa76a54ec20b6ce78588 = $(`&lt;div id=&quot;html_22cb308d4381fa76a54ec20b6ce78588&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_72de41b1f68cabfbd9ae7992ef9be46b.setContent(html_22cb308d4381fa76a54ec20b6ce78588);
#
#
#         marker_7eed80f3234357a6d78d586f8bf91294.bindPopup(popup_72de41b1f68cabfbd9ae7992ef9be46b)
#         ;
#
#
#
#
#             var marker_0a24cb9be88e2769164ece6d80cebce7 = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_83b3f7107cf9899868137e567f1c1ecf);
#
#
#         var popup_04ef082841978e12c29a66c0b8466112 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e2ab1839291b157402defe680fd1bad3 = $(`&lt;div id=&quot;html_e2ab1839291b157402defe680fd1bad3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_04ef082841978e12c29a66c0b8466112.setContent(html_e2ab1839291b157402defe680fd1bad3);
#
#
#         marker_0a24cb9be88e2769164ece6d80cebce7.bindPopup(popup_04ef082841978e12c29a66c0b8466112)
#         ;
#
#
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format
