# %%
import folium
import pandas as pd
import numpy as np
from sympy import *
import matplotlib.pyplot as plt

DAEGU = [35.85, 128.56]
KADIZ = [(39.00, 123.30),
         (37.00, 124.00),
         (30.00, 124.00),
         (30.00, 124.00),
         (30.00, 125.25),
         (30.00, 125.25),
         (32.30, 126.50),
         (32.30, 127.30),
         (34.17, 128.52),
         (35.13, 129.48),
         (36.00, 130.30),
         (37.17, 133.00),
         (39.00, 133.00),
         (39.00, 123.30)]
IEODO = [32.11753829417425, 125.16666665729801]
DOKDO = [37.24315823449135, 131.86690646281266]

def init_map():
    m = folium.Map(location = DAEGU, zoom_start = 5.5)
    folium.PolyLine(locations = KADIZ,tooltip = 'KADIZ', color='red').add_to(m)
    folium.Marker(IEODO, popup="<i>IEODO</i>").add_to(m)
    folium.Marker(DOKDO, popup="<i>DOKDO</i>").add_to(m)
    return m

m = init_map()

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba7a0a129d202f622131a00ca63ebd67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba7a0a129d202f622131a00ca63ebd67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ba7a0a129d202f622131a00ca63ebd67 = L.map(
#                 &quot;map_ba7a0a129d202f622131a00ca63ebd67&quot;,
#                 {
#                     center: [35.85, 128.56],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e34356ad6729dbcf5bb0124e1965296 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba7a0a129d202f622131a00ca63ebd67);
#
#
#             var poly_line_74679904233dd297afd980cfd06a4cd1 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba7a0a129d202f622131a00ca63ebd67);
#
#
#             poly_line_74679904233dd297afd980cfd06a4cd1.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_276604e9cca52796d7977084f0723668 = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_ba7a0a129d202f622131a00ca63ebd67);
#
#
#         var popup_2bcd8896b2dc1e668fa1c20e429fed31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4e7e51fe6617fcfe6d4e50ecf2eafefc = $(`&lt;div id=&quot;html_4e7e51fe6617fcfe6d4e50ecf2eafefc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_2bcd8896b2dc1e668fa1c20e429fed31.setContent(html_4e7e51fe6617fcfe6d4e50ecf2eafefc);
#
#
#         marker_276604e9cca52796d7977084f0723668.bindPopup(popup_2bcd8896b2dc1e668fa1c20e429fed31)
#         ;
#
#
#
#
#             var marker_8383aa43afd32e5d65a8412335530963 = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_ba7a0a129d202f622131a00ca63ebd67);
#
#
#         var popup_4a078400b28f52917d72767d5383eba1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5a7c07df362d81958a976d4d38cc59f3 = $(`&lt;div id=&quot;html_5a7c07df362d81958a976d4d38cc59f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_4a078400b28f52917d72767d5383eba1.setContent(html_5a7c07df362d81958a976d4d38cc59f3);
#
#
#         marker_8383aa43afd32e5d65a8412335530963.bindPopup(popup_4a078400b28f52917d72767d5383eba1)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def mk_row(point):
    x, y = point
    return [y * y, x, y, x * y, 1]

#return value (a, b, c, d, e, f) matches (ax^2 + by^2 + cx + by + exy + f = 0)
def find_ellipse(points):
    if len(points) != 5:
        raise ValueError
    else:
        mat = []
        constant = []
        for point in points:
            mat.append(mk_row(point))
            constant.append(-point[0]**2)
        sol = np.linalg.solve(np.array(mat), constant)
    return np.concatenate((np.array([1]), sol), axis = None)

def make_route(sol, data, input_axis, select):
    x = symbols('x', real = True)
    y = symbols('y', real = True)
    a, b, c, d, e, f = sol
    route = []
    if input_axis == 'x':
        for i in data:
            x = i
            ans = solve(a*x**2 + b*y**2 + c*x + d*y + e*x*y + f)
            if len(ans) == 0:
                print('No real solution at {}'.format(i))
                break
            if select == 'max':
                y_sol = max(ans)
                route.append([y_sol, i])
            elif select == 'min':
                y_sol = min(ans)
                route.append([y_sol, i])
    elif input_axis == 'y':
        for i in data:
            y = i
            ans = solve(a*x**2 + b*y**2 + c*x + d*y + e*x*y + f)
            if len(ans) == 0:
                print('No real solution at {}'.format(i))
                break
            if select == 'max':
                x_sol = max(ans)
                route.append([i, x_sol])
            elif select == 'min':
                x_sol = min(ans)
                route.append([i, x_sol])
    return route

# %%
# Make base route
points = [(120.15, 29.331), (125.8, 31.369), (127.42, 32.459), (129.44, 34.436), (131.35, 38.448)]

sol = find_ellipse(points)

lat_range = np.linspace(123, 131, 100)
base_route = np.array(make_route(sol, lat_range, 'x', 'min'))

# print(len(route_1), route_1)

# %%
folium.PolyLine(locations = base_route, tooltip = 'flight tracks', color = 'blue').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_676b9f0a06b89988d39419ff0402e4d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_676b9f0a06b89988d39419ff0402e4d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_676b9f0a06b89988d39419ff0402e4d2 = L.map(
#                 &quot;map_676b9f0a06b89988d39419ff0402e4d2&quot;,
#                 {
#                     center: [35.85, 128.56],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9df2332c587c6cc076102e913aaacdcc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_676b9f0a06b89988d39419ff0402e4d2);
#
#
#             var poly_line_4dcbd39134e7f6fd5749e04a0e28efb5 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_676b9f0a06b89988d39419ff0402e4d2);
#
#
#             poly_line_4dcbd39134e7f6fd5749e04a0e28efb5.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2b18a4a9ff2b08587627d3d50bdf3672 = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_676b9f0a06b89988d39419ff0402e4d2);
#
#
#         var popup_a13093a63ab26e7e34d9f440ac5442c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_07b5f834c3ead3774bd817353d245537 = $(`&lt;div id=&quot;html_07b5f834c3ead3774bd817353d245537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_a13093a63ab26e7e34d9f440ac5442c9.setContent(html_07b5f834c3ead3774bd817353d245537);
#
#
#         marker_2b18a4a9ff2b08587627d3d50bdf3672.bindPopup(popup_a13093a63ab26e7e34d9f440ac5442c9)
#         ;
#
#
#
#
#             var marker_35e823019bbf2ee74b83c9652b4ab4db = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_676b9f0a06b89988d39419ff0402e4d2);
#
#
#         var popup_09df5f5bb275ba5c224d3f6b8bd040c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e0ecf79fdcba4fb37cbcb54ea1518f6 = $(`&lt;div id=&quot;html_7e0ecf79fdcba4fb37cbcb54ea1518f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_09df5f5bb275ba5c224d3f6b8bd040c7.setContent(html_7e0ecf79fdcba4fb37cbcb54ea1518f6);
#
#
#         marker_35e823019bbf2ee74b83c9652b4ab4db.bindPopup(popup_09df5f5bb275ba5c224d3f6b8bd040c7)
#         ;
#
#
#
#
#             var poly_line_93fa6b4f7a05fb100a896fba4d5d7fa2 = L.polyline(
#                 [[30.08496574842451, 123.0], [30.113682093076296, 123.08080808080808], [30.14284069908697, 123.16161616161617], [30.172445418339677, 123.24242424242425], [30.202500209824336, 123.32323232323232], [30.23300914307726, 123.4040404040404], [30.263976401764914, 123.48484848484848], [30.29540628744561, 123.56565656565657], [30.327303223492983, 123.64646464646465], [30.35967175921528, 123.72727272727273], [30.392516574156396, 123.8080808080808], [30.42584248261551, 123.88888888888889], [30.45965443837168, 123.96969696969697], [30.493957539649124, 124.05050505050505], [30.52875703431622, 124.13131313131314], [30.564058325353557, 124.21212121212122], [30.599866976582835, 124.29292929292929], [30.636188718701412, 124.37373737373737], [30.673029455609452, 124.45454545454545], [30.710395271080436, 124.53535353535354], [30.748292435765478, 124.61616161616162], [30.786727414584643, 124.6969696969697], [30.825706874495438, 124.77777777777777], [30.86523769270184, 124.85858585858585], [30.90532696529723, 124.93939393939394], [30.94598201639103, 125.02020202020202], [30.98721040775669, 125.1010101010101], [31.029019949010184, 125.18181818181819], [31.071418708395406, 125.26262626262627], [31.114415024175987, 125.34343434343434], [31.15801751671947, 125.42424242424242], [31.202235101287794, 125.5050505050505], [31.24707700161698, 125.58585858585859], [31.29255276431633, 125.66666666666667], [31.338672274179455, 125.74747474747475], [31.3854457704471

# %%
# make noise
mu, sigma = 0.1, 0.01
route_dataset = []

for i in range(100):
    s = np.random.default_rng(i).normal(mu, sigma, size=(100, 2))
    route_dataset.append(base_route + s)

route_dataset = np.array(route_dataset)
print(route_dataset.shape)
# print(route_dataset[0])
# Out:
# (100, 100, 2)

# %%
# show one route in dataset 
folium.PolyLine(locations = route_dataset[0], tooltip = 'track with noise', color = 'orange').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_676b9f0a06b89988d39419ff0402e4d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_676b9f0a06b89988d39419ff0402e4d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_676b9f0a06b89988d39419ff0402e4d2 = L.map(
#                 &quot;map_676b9f0a06b89988d39419ff0402e4d2&quot;,
#                 {
#                     center: [35.85, 128.56],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9df2332c587c6cc076102e913aaacdcc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_676b9f0a06b89988d39419ff0402e4d2);
#
#
#             var poly_line_4dcbd39134e7f6fd5749e04a0e28efb5 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_676b9f0a06b89988d39419ff0402e4d2);
#
#
#             poly_line_4dcbd39134e7f6fd5749e04a0e28efb5.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2b18a4a9ff2b08587627d3d50bdf3672 = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_676b9f0a06b89988d39419ff0402e4d2);
#
#
#         var popup_a13093a63ab26e7e34d9f440ac5442c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_07b5f834c3ead3774bd817353d245537 = $(`&lt;div id=&quot;html_07b5f834c3ead3774bd817353d245537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_a13093a63ab26e7e34d9f440ac5442c9.setContent(html_07b5f834c3ead3774bd817353d245537);
#
#
#         marker_2b18a4a9ff2b08587627d3d50bdf3672.bindPopup(popup_a13093a63ab26e7e34d9f440ac5442c9)
#         ;
#
#
#
#
#             var marker_35e823019bbf2ee74b83c9652b4ab4db = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_676b9f0a06b89988d39419ff0402e4d2);
#
#
#         var popup_09df5f5bb275ba5c224d3f6b8bd040c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e0ecf79fdcba4fb37cbcb54ea1518f6 = $(`&lt;div id=&quot;html_7e0ecf79fdcba4fb37cbcb54ea1518f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_09df5f5bb275ba5c224d3f6b8bd040c7.setContent(html_7e0ecf79fdcba4fb37cbcb54ea1518f6);
#
#
#         marker_35e823019bbf2ee74b83c9652b4ab4db.bindPopup(popup_09df5f5bb275ba5c224d3f6b8bd040c7)
#         ;
#
#
#
#
#             var poly_line_93fa6b4f7a05fb100a896fba4d5d7fa2 = L.polyline(
#                 [[30.08496574842451, 123.0], [30.113682093076296, 123.08080808080808], [30.14284069908697, 123.16161616161617], [30.172445418339677, 123.24242424242425], [30.202500209824336, 123.32323232323232], [30.23300914307726, 123.4040404040404], [30.263976401764914, 123.48484848484848], [30.29540628744561, 123.56565656565657], [30.327303223492983, 123.64646464646465], [30.35967175921528, 123.72727272727273], [30.392516574156396, 123.8080808080808], [30.42584248261551, 123.88888888888889], [30.45965443837168, 123.96969696969697], [30.493957539649124, 124.05050505050505], [30.52875703431622, 124.13131313131314], [30.564058325353557, 124.21212121212122], [30.599866976582835, 124.29292929292929], [30.636188718701412, 124.37373737373737], [30.673029455609452, 124.45454545454545], [30.710395271080436, 124.53535353535354], [30.748292435765478, 124.61616161616162], [30.786727414584643, 124.6969696969697], [30.825706874495438, 124.77777777777777], [30.86523769270184, 124.85858585858585], [30.90532696529723, 124.93939393939394], [30.94598201639103, 125.02020202020202], [30.98721040775669, 125.1010101010101], [31.029019949010184, 125.18181818181819], [31.071418708395406, 125.26262626262627], [31.114415024175987, 125.34343434343434], [31.15801751671947, 125.42424242424242], [31.202235101287794, 125.5050505050505], [31.24707700161698, 125.58585858585859], [31.29255276431633, 125.66666666666667], [31.338672274179455, 125.74747474747475], [31.3854457704471

# %%
# Split datasets
ratio = 0.7
boundary = int(len(route_dataset) * ratio)

train_dataset = route_dataset[:boundary, :, :]
test_dataset = route_dataset[boundary:, :, :]

print(train_dataset.shape, test_dataset.shape)
# Out:
# (70, 100, 2) (30, 100, 2)

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler , MinMaxScaler

class RouteDataset(Dataset): 
    def __init__(self, train=True):    
        # Scaling
        self.minmax = MinMaxScaler()
        self.standard = StandardScaler()
        self.dataset = train_dataset if train == True else test_dataset
        
        self.x_data = standard.fit_transform(self.dataset.reshape(-1, self.dataset.shape[-1])).reshape(self.dataset.shape)
        self.y_data = minmax.fit_transform(self.dataset.reshape(-1, self.dataset.shape[-1])).reshape(self.dataset.shape)
            
    def __len__(self): 
        return len(self.x_data)
    
    def __getitem__(self, idx): 
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        return x, y

# %%
batch_size = 16

train_loader = DataLoader(dataset=RouteDataset(train=True), 
                          batch_size=batch_size, 
                          shuffle=True)
test_loader = DataLoader(dataset=RouteDataset(train=False), 
                         batch_size=batch_size, 
                         shuffle=True)

# %%
# Model definition
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

device = 'cpu'

class LSTM(nn.Module):
    def __init__(self,num_classes,input_size,hidden_size,num_layers,seq_length):
        super(LSTM,self).__init__()
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length

        self.lstm = nn.LSTM(input_size=input_size , hidden_size=hidden_size , num_layers=num_layers, batch_first=True)
        self.fc_1 = nn.Linear(hidden_size,128)
        self.fc = nn.Linear(128,num_classes)

        self.relu = nn.ReLU()

    def forward(self,x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0),self.hidden_size)).to(device)
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0),self.hidden_size)).to(device)

        output, (hn,cn) = self.lstm(x,(h_0,c_0))

        hn = hn.view(-1, self.hidden_size)
        out = self.relu(hn)
        out = self.fc_1(out)
        out = self.relu(out)
        out = self.fc(out)
        return out

# %%
num_epochs = 1000
learning_rate = 0.001

input_size = 2
hidden_size = 4
num_layers = 1
num_classes = 2
seq_length = 100

print_every = 100
n_iter = 0

model = LSTM(num_classes, input_size, hidden_size, num_layers, seq_length)
loss_function = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
# Model training
for epoch in range(num_epochs):
    for i, (x_train, y_train) in enumerate(train_loader):
        x_train = Variable(x_train.view(-1, seq_length, input_size))
        y_train = Variable(y_train)
        
        optimizer.zero_grad()
        outputs = model.forward(x_train)
#         import pdb; pdb.set_trace()
        loss = loss_function(outputs, y_train)
        
        loss.backward()
        optimizer.step()
        n_iter += 1
        
        if epoch % print_every == 0:
            print("Epoch : %d, loss : %1.5f" % (epoch, loss.item()))
# Out:
# > /var/folders/c9/y3tyld_57fx2xmp_h_mhwwfr0000gn/T/ipykernel_55808/1282784493.py(10)<module>()
#       8         outputs = model.forward(x_train)
#       9         import pdb; pdb.set_trace()
# ---> 10         loss = loss_function(outputs, y_train)
#      11
#      12         loss.backward()
#
# ipdb> outputs.shape
# torch.Size([16, 2])
# ipdb> y_train.shape
# torch.Size([16, 100, 2])
# ipdb> quit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# /var/folders/c9/y3tyld_57fx2xmp_h_mhwwfr0000gn/T/ipykernel_55808/1282784493.py in <module>
#       8         outputs = model.forward(x_train)
#       9         import pdb; pdb.set_trace()
# ---> 10         loss = loss_function(outputs, y_train)
#      11
#      12         loss.backward()
#
# /var/folders/c9/y3tyld_57fx2xmp_h_mhwwfr0000gn/T/ipykernel_55808/1282784493.py in <module>
#       8         outputs = model.forward(x_train)
#       9         import pdb; pdb.set_trace()
# ---> 10         loss = loss_function(outputs, y_train)
#      11
#      12         loss.backward()
#
# ~/opt/anaconda3/envs/torch_book/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~/opt/anaconda3/envs/torch_book/lib/python3.7/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# # 아래는 옛날 코드

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import pandas as pd

device = 'cpu'

# %%
class LSTM(nn.Module):
    def __init__(self,num_classes,input_size,hidden_size,num_layers,seq_length):
        super(LSTM,self).__init__()
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length

        self.lstm = nn.LSTM(input_size = input_size , hidden_size = hidden_size , num_layers = num_layers, batch_first = True)
        self.fc_1 = nn.Linear(hidden_size,128)
        self.fc = nn.Linear(128,num_classes)

        self.relu = nn.ReLU()

    def forward(self,x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0),self.hidden_size)).to(device)
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0),self.hidden_size)).to(device)

        output, (hn,cn) = self.lstm(x,(h_0,c_0))

        hn = hn.view(-1,self.hidden_size)
        out = self.relu(hn)
        out = self.fc_1(out)
        out = self.relu(out)
        out = self.fc(out)
        return out

# %%
df = pd.DataFrame(route)
y = df.iloc[:,0:]

df[0] = df[0].astype(float)

print(df.dtypes)
print(df.shape)
# Out:
# 0    float64
# 1    float64
# dtype: object
# (100, 2)

# %%
def split_train_test(data,test_ratio):
    train_set_size = int(len(data)*(1 - test_ratio))
    train_indices = data[:train_set_size]
    test_indices = data[train_set_size:]
    return train_indices,test_indices

train_set,test_set = split_train_test(df.values,0.2)

# %%
from sklearn.preprocessing import StandardScaler , MinMaxScaler

minmax = MinMaxScaler()
standard = StandardScaler()
x_ss = standard.fit_transform(df)
y_mm = minmax.fit_transform(y)
x_train, x_test = split_train_test(x_ss,0.)
y_train, y_test = split_train_test(y_mm,0.)

x_train_tensors = Variable(torch.Tensor(x_train))
x_test_tensors = Variable(torch.Tensor(x_test))
y_train_tensors = Variable(torch.Tensor(y_train))
y_test_tensors = Variable(torch.Tensor(y_test))
x_train_final = torch.reshape(x_train_tensors,(x_train_tensors.shape[0],1,x_train_tensors.shape[1]))
x_test_final = torch.reshape(x_test_tensors,(x_test_tensors.shape[0],1,x_test_tensors.shape[1]))

# print(x_train_final.shape, x_train_final)
# print(y_train_tensors.shape, y_train_tensors)

# %%
num_epochs = 6000
learning_rate = 0.0001
input_size = 2
hidden_size = 4
num_layers = 1
num_classes = 2

model = LSTM(num_classes, input_size, hidden_size, num_layers, x_train_final.shape[1]).to(device)

loss_function = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
for epoch in range(num_epochs):
    outputs = model.forward(x_train_final.to(device))
    optimizer.zero_grad()
    loss = loss_function(outputs, y_train_tensors.to(device))
    
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        print("Epoch : %d, loss : %1.5f" % (epoch,loss.item()))
# Out:
# Epoch : 0, loss : 0.35840
# Epoch : 100, loss : 0.21322
# Epoch : 200, loss : 0.13704
# Epoch : 300, loss : 0.10042
# Epoch : 400, loss : 0.08266
# Epoch : 500, loss : 0.07169
# Epoch : 600, loss : 0.06211
# Epoch : 700, loss : 0.05170
# Epoch : 800, loss : 0.03995
# Epoch : 900, loss : 0.02781
# Epoch : 1000, loss : 0.01782
# Epoch : 1100, loss : 0.01122
# Epoch : 1200, loss : 0.00750
# Epoch : 1300, loss : 0.00572
# Epoch : 1400, loss : 0.00473
# Epoch : 1500, loss : 0.00396
# Epoch : 1600, loss : 0.00331
# Epoch : 1700, loss : 0.00272
# Epoch : 1800, loss : 0.00225
# Epoch : 1900, loss : 0.00184
# Epoch : 2000, loss : 0.00150
# Epoch : 2100, loss : 0.00114
# Epoch : 2200, loss : 0.00086
# Epoch : 2300, loss : 0.00067
# Epoch : 2400, loss : 0.00053
# Epoch : 2500, loss : 0.00043
# Epoch : 2600, loss : 0.00035
# Epoch : 2700, loss : 0.00029
# Epoch : 2800, loss : 0.00024
# Epoch : 2900, loss : 0.00021
# Epoch : 3000, loss : 0.00018
# Epoch : 3100, loss : 0.00015
# Epoch : 3200, loss : 0.00013
# Epoch : 3300, loss : 0.00011
# Epoch : 3400, loss : 0.00010
# Epoch : 3500, loss : 0.00008
# Epoch : 3600, loss : 0.00007
# Epoch : 3700, loss : 0.00006
# Epoch : 3800, loss : 0.00005
# Epoch : 3900, loss : 0.00004
# Epoch : 4000, loss : 0.00004
# Epoch : 4100, loss : 0.00003
# Epoch : 4200, loss : 0.00003
# Epoch : 4300, loss : 0.00003
# Epoch : 4400, loss : 0.00002
# Epoch : 4500, loss : 0.00002
# Epoch : 4600, loss : 0.00002
# Epoch : 4700, loss : 0.00002
# Epoch : 4800, loss : 0.00001
# Epoch : 4900, loss : 0.00001
# Epoch : 5000, loss : 0.00001
# Epoch : 5100, loss : 0.00001
# Epoch : 5200, loss : 0.00001
# Epoch : 5300, loss : 0.00001
# Epoch : 5400, loss : 0.00001
# Epoch : 5500, loss : 0.00001
# Epoch : 5600, loss : 0.00001
# Epoch : 5700, loss : 0.00001
# Epoch : 5800, loss : 0.00001
# Epoch : 5900, loss : 0.00001

# %%
df_X_ss = standard.transform(df)
df_y_mm = minmax.transform(y)
df_X_ss = Variable(torch.Tensor(df_X_ss))
df_y_mm = Variable(torch.Tensor(df_y_mm))
df_X_ss = torch.reshape(df_X_ss , (df_X_ss.shape[0],1,df_X_ss.shape[1]))

# %%
train_predict = model(df_X_ss)
data_predict = train_predict.data.detach().cpu().numpy()
dataY_plot = df_y_mm.data.numpy()

data_predict = minmax.inverse_transform(data_predict)

# %%
f1 = folium.PolyLine(locations = data_predict,color = 'green',tooltip = 'Predicted Trajectory')
f1.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_712e1dc6f6d6c7a09971b78f6b0b3932 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_712e1dc6f6d6c7a09971b78f6b0b3932&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_712e1dc6f6d6c7a09971b78f6b0b3932 = L.map(
#                 &quot;map_712e1dc6f6d6c7a09971b78f6b0b3932&quot;,
#                 {
#                     center: [35.85, 128.56],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4278d75b6465aa426571187520badc5c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_712e1dc6f6d6c7a09971b78f6b0b3932);
#
#
#             var poly_line_d50d780f4b3bf9428fb9a1a548079e60 = L.polyline(
#                 [[39.0, 123.3], [37.0, 124.0], [30.0, 124.0], [30.0, 124.0], [30.0, 125.25], [30.0, 125.25], [32.3, 126.5], [32.3, 127.3], [34.17, 128.52], [35.13, 129.48], [36.0, 130.3], [37.17, 133.0], [39.0, 133.0], [39.0, 123.3]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_712e1dc6f6d6c7a09971b78f6b0b3932);
#
#
#             poly_line_d50d780f4b3bf9428fb9a1a548079e60.bindTooltip(
#                 `&lt;div&gt;
#                      KADIZ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0dd43030d655bfc9f95be505e4cef050 = L.marker(
#                 [32.11753829417425, 125.16666665729801],
#                 {}
#             ).addTo(map_712e1dc6f6d6c7a09971b78f6b0b3932);
#
#
#         var popup_8c1ad751feb4587bd132224e80c8043d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b2f703105b6fdc73e2cfa7ffce4f13aa = $(`&lt;div id=&quot;html_b2f703105b6fdc73e2cfa7ffce4f13aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;IEODO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_8c1ad751feb4587bd132224e80c8043d.setContent(html_b2f703105b6fdc73e2cfa7ffce4f13aa);
#
#
#         marker_0dd43030d655bfc9f95be505e4cef050.bindPopup(popup_8c1ad751feb4587bd132224e80c8043d)
#         ;
#
#
#
#
#             var marker_4d9acf9bef7c10ba5a897a734d896afd = L.marker(
#                 [37.24315823449135, 131.86690646281266],
#                 {}
#             ).addTo(map_712e1dc6f6d6c7a09971b78f6b0b3932);
#
#
#         var popup_fa23b42860e9e75aa886b42111723ac4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_89989e681d4527109183aa8ab9b76586 = $(`&lt;div id=&quot;html_89989e681d4527109183aa8ab9b76586&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;DOKDO&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_fa23b42860e9e75aa886b42111723ac4.setContent(html_89989e681d4527109183aa8ab9b76586);
#
#
#         marker_4d9acf9bef7c10ba5a897a734d896afd.bindPopup(popup_fa23b42860e9e75aa886b42111723ac4)
#         ;
#
#
#
#
#             var poly_line_d690a1736193d7e65688bec63dff6078 = L.polyline(
#                 [[30.08496574842451, 123.0], [30.113682093076296, 123.08080808080808], [30.14284069908697, 123.16161616161617], [30.172445418339677, 123.24242424242425], [30.202500209824336, 123.32323232323232], [30.23300914307726, 123.4040404040404], [30.263976401764914, 123.48484848484848], [30.29540628744561, 123.56565656565657], [30.327303223492983, 123.64646464646465], [30.35967175921528, 123.72727272727273], [30.392516574156396, 123.8080808080808], [30.42584248261551, 123.88888888888889], [30.45965443837168, 123.96969696969697], [30.493957539649124, 124.05050505050505], [30.52875703431622, 124.13131313131314], [30.564058325353557, 124.21212121212122], [30.599866976582835, 124.29292929292929], [30.636188718701412, 124.37373737373737], [30.673029455609452, 124.45454545454545], [30.710395271080436, 124.53535353535354], [30.748292435765478, 124.61616161616162], [30.786727414584643, 124.6969696969697], [30.825706874495438, 124.77777777777777], [30.86523769270184, 124.85858585858585], [30.90532696529723, 124.93939393939394], [30.94598201639103, 125.02020202020202], [30.98721040775669, 125.1010101010101], [31.029019949010184, 125.18181818181819], [31.071418708395406, 125.26262626262627], [31.114415024175987, 125.34343434343434], [31.15801751671947, 125.42424242424242], [31.202235101287794, 125.5050505050505], [31.24707700161698, 125.58585858585859], [31.29255276431633, 125.66666666666667], [31.338672274179455, 125.74747474747475], [31.3854457704471
